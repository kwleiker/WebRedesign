# %%
# Dependencies and Setup
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import requests 
import time 


import os
import csv
import matplotlib.pyplot as plt
import itertools as it
from matplotlib import cm
 
import seaborn as sns
import pandas as pd
plt.style.use('seaborn')

    # because you never know...  maybe I'll do things with this.


# Output File (CSV)
# %cd "C:\Users\kwlei\Documents\GitHub\Web-Design-Challenge\WebVisualizations\assets"
## output_data_file = "resources/cities.csv"

# Import API key
from api_key import api_key 
from citipy import citipy 


  #  Range of latitudes and longitudes
  #  lat_range = (-58, 73)
  #  lng_range = (-180, 180)


# produce some output 
print("some output")
# Out:
# C:\Users\kwlei\Documents\GitHub\Web-Design-Challenge\WebVisualizations\assets
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-351f962ff2f4> in <module>
#      25
#      26 # Import API key
# ---> 27 from api_key import api_key
#      28 from citipy import citipy
#      29
#
# ModuleNotFoundError: No module named 'api_key'

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

### It would be better to select randomly within a grid pattern (ie bins 10 degrees NS by 15 EW). 
### That would result in greater over-sampling of cities in sparsely populated areas,
###   thus giving better spread on the coverage. 

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


#  utu /watch?v=AVF-HyplZqo @ T:s=300

cityGrab_df = pd.DataFrame(cities, columns=["NAME"])
cityGrab_df.to_csv('cityGrab.csv', index=False)




# Print the city count to confirm sufficient count
# len(cities) 
len(cities)
# Out:
# 625

# %%
# Starting URL for Weather Map API Call
api_key = api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

city_data = []

print("starting the API query")
print("APIS is Latin for bee")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
        if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # this is prints where you are at so far.
    city_url = url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    record_count += 1

# I like that the command is called try
    try:
        city_weather = requests.get(city_url).json()

        # Nate used to say, "Does that parse?" in place of "did that make sense?"
        # He was stoned from years and he needed to make check often. 
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "MaxTemp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "WindSpeed": city_wind, 
                          "Country": city_country, 
                          "Date": city_date})

# I LOVE THIS COMMAND
    except:
        print("City not found. Skipping...")
        pass
              
# EFF that took a long time
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 1 | aban
# City not found. Skipping...
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | ballina
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | leningradskiy
# Processing Record 8 of Set 1 | maltahohe
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | panama city
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | faanui
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | cockburn town
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | pisco
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | humaita
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | konstantinovka
# Processing Record 27 of Set 1 | jardim
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | the valley
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | walvis bay
# Processing Record 32 of Set 1 | hasaki
# Processing Record 33 of Set 1 | whitehorse
# Processing Record 34 of Set 1 | cururupu
# Processing Record 35 of Set 1 | souillac
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | culpeper
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | benjamin constant
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | bartica
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | dover
# Processing Record 49 of Set 1 | airai
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 0 of Set 2 | saint george
# Processing Record 1 of Set 2 | mahe
# Processing Record 2 of Set 2 | tarko-sale
# Processing Record 3 of Set 2 | san policarpo
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | duz
# City not found. Skipping...
# Processing Record 6 of Set 2 | kolokani
# Processing Record 7 of Set 2 | unai
# Processing Record 8 of Set 2 | shingu
# Processing Record 9 of Set 2 | lander
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | kavaratti
# Processing Record 13 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | jinchengjiang
# City not found. Skipping...
# Processing Record 16 of Set 2 | muros
# Processing Record 17 of Set 2 | bandarbeyla
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | ajaccio
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | fuzhou
# Processing Record 25 of Set 2 | perivolion
# Processing Record 26 of Set 2 | saurimo
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | korla
# City not found. Skipping...
# Processing Record 30 of Set 2 | bowen
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | lavrentiya
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | abilene
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | alice springs
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | poum
# Processing Record 43 of Set 2 | vila franca do campo
# Processing Record 44 of Set 2 | henties bay
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | lasa
# Processing Record 48 of Set 2 | mataura
# Processing Record 49 of Set 2 | sitka
# Processing Record 0 of Set 3 | santa quiteria
# Processing Record 1 of Set 3 | byron bay
# Processing Record 2 of Set 3 | totma
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | rawlins
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | kolno
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | hami
# Processing Record 9 of Set 3 | eyl
# Processing Record 10 of Set 3 | arkhipo-osipovka
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 3 | fasa
# Processing Record 14 of Set 3 | ancud
# Processing Record 15 of Set 3 | komsomolskiy
# Processing Record 16 of Set 3 | pimentel
# Processing Record 17 of Set 3 | touros
# Processing Record 18 of Set 3 | rawson
# Processing Record 19 of Set 3 | luanda
# Processing Record 20 of Set 3 | fukue
# Processing Record 21 of Set 3 | pedasi
# Processing Record 22 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 3 | aragarcas
# Processing Record 24 of Set 3 | kidal
# Processing Record 25 of Set 3 | tessalit
# Processing Record 26 of Set 3 | narsaq
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | san carlos
# Processing Record 30 of Set 3 | tiarei
# Processing Record 31 of Set 3 | batagay
# Processing Record 32 of Set 3 | port hardy
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | hofn
# Processing Record 35 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 3 | bengkulu
# City not found. Skipping...
# Processing Record 37 of Set 3 | puerto ayora
# Processing Record 38 of Set 3 | atuona
# Processing Record 39 of Set 3 | luau
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | bakchar
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | mayskiy
# Processing Record 44 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 3 | bereda
# Processing Record 46 of Set 3 | quatre cocos
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | fortuna
# Processing Record 49 of Set 3 | chuy
# Processing Record 0 of Set 4 | matay
# Processing Record 1 of Set 4 | xichang
# Processing Record 2 of Set 4 | san cristobal
# Processing Record 3 of Set 4 | eirunepe
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | guerrero negro
# Processing Record 6 of Set 4 | corn island
# Processing Record 7 of Set 4 | haines junction
# Processing Record 8 of Set 4 | potam
# Processing Record 9 of Set 4 | kapaa
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | paijan
# Processing Record 12 of Set 4 | vao
# Processing Record 13 of Set 4 | barmer
# Processing Record 14 of Set 4 | rio gallegos
# Processing Record 15 of Set 4 | mwene-ditu
# Processing Record 16 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 4 | moerai
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | minot
# Processing Record 20 of Set 4 | aklavik
# Processing Record 21 of Set 4 | marianske lazne
# Processing Record 22 of Set 4 | port hawkesbury
# Processing Record 23 of Set 4 | vista
# Processing Record 24 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 4 | shache
# Processing Record 28 of Set 4 | hermiston
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | guasdualito
# Processing Record 31 of Set 4 | kahului
# Processing Record 32 of Set 4 | vieux-habitants
# Processing Record 33 of Set 4 | krylovskaya
# Processing Record 34 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 4 | paita
# Processing Record 36 of Set 4 | vilyuysk
# Processing Record 37 of Set 4 | seoul
# Processing Record 38 of Set 4 | mayo
# Processing Record 39 of Set 4 | dhidhdhoo
# Processing Record 40 of Set 4 | zambezi
# Processing Record 41 of Set 4 | avera
# Processing Record 42 of Set 4 | camacha
# Processing Record 43 of Set 4 | rockford
# Processing Record 44 of Set 4 | waingapu
# Processing Record 45 of Set 4 | chokurdakh
# Processing Record 46 of Set 4 | tarsus
# Processing Record 47 of Set 4 | isiro
# Processing Record 48 of Set 4 | yulara
# Processing Record 49 of Set 4 | camapua
# Processing Record 0 of Set 5 | jalu
# Processing Record 1 of Set 5 | nhulunbuy
# Processing Record 2 of Set 5 | pinheiro machado
# Processing Record 3 of Set 5 | changji
# Processing Record 4 of Set 5 | west odessa
# Processing Record 5 of Set 5 | bata
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | leon
# Processing Record 9 of Set 5 | macduff
# Processing Record 10 of Set 5 | bucerias
# Processing Record 11 of Set 5 | bambanglipuro
# Processing Record 12 of Set 5 | dolores
# Processing Record 13 of Set 5 | areia branca
# Processing Record 14 of Set 5 | sao filipe
# Processing Record 15 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 5 | vardo
# Processing Record 17 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 5 | praia da vitoria
# Processing Record 19 of Set 5 | sorland
# Processing Record 20 of Set 5 | marawi
# Processing Record 21 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 5 | north bend
# Processing Record 23 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 24 of Set 5 | vikhorevka
# Processing Record 25 of Set 5 | rio grande
# Processing Record 26 of Set 5 | muscatine
# Processing Record 27 of Set 5 | tilichiki
# Processing Record 28 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 5 | ilulissat
# Processing Record 30 of Set 5 | vodnyy
# Processing Record 31 of Set 5 | kavieng
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | acoyapa
# Processing Record 34 of Set 5 | pevek
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | sumenep
# Processing Record 37 of Set 5 | obidos
# Processing Record 38 of Set 5 | kumertau
# Processing Record 39 of Set 5 | grajau
# City not found. Skipping...
# Processing Record 40 of Set 5 | westport
# Processing Record 41 of Set 5 | urengoy
# Processing Record 42 of Set 5 | kutum
# Processing Record 43 of Set 5 | santa cruz
# Processing Record 44 of Set 5 | kyra
# City not found. Skipping...
# Processing Record 45 of Set 5 | inhambane
# Processing Record 46 of Set 5 | khakhea
# Processing Record 47 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 5 | baykit
# Processing Record 49 of Set 5 | port augusta
# Processing Record 0 of Set 6 | wichian buri
# Processing Record 1 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 6 | port-gentil
# Processing Record 3 of Set 6 | ekibastuz
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | kampot
# Processing Record 6 of Set 6 | doha
# Processing Record 7 of Set 6 | murgab
# Processing Record 8 of Set 6 | qaqortoq
# Processing Record 9 of Set 6 | pulandian
# Processing Record 10 of Set 6 | chivilcoy
# Processing Record 11 of Set 6 | galesong
# Processing Record 12 of Set 6 | bonavista
# Processing Record 13 of Set 6 | jumla
# Processing Record 14 of Set 6 | tayoltita
# Processing Record 15 of Set 6 | macau
# Processing Record 16 of Set 6 | tamala
# Processing Record 17 of Set 6 | mednogorsk
# Processing Record 18 of Set 6 | fuling
# Processing Record 19 of Set 6 | kirksville
# Processing Record 20 of Set 6 | paamiut
# Processing Record 21 of Set 6 | itarema
# Processing Record 22 of Set 6 | tapa
# Processing Record 23 of Set 6 | itamarandiba
# Processing Record 24 of Set 6 | morant bay
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | vilhena
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | abu samrah
# Processing Record 29 of Set 6 | koupela
# Processing Record 30 of Set 6 | tasiilaq
# Processing Record 31 of Set 6 | pangai
# Processing Record 32 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 6 | dikson
# Processing Record 34 of Set 6 | laguna
# Processing Record 35 of Set 6 | andenes
# City not found. Skipping...
# Processing Record 36 of Set 6 | lodwar
# Processing Record 37 of Set 6 | iskateley
# Processing Record 38 of Set 6 | pacific grove
# Processing Record 39 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 6 | esperance
# Processing Record 41 of Set 6 | nikolayevsk-na-amure
# Processing Record 42 of Set 6 | tucuman
# Processing Record 43 of Set 6 | hamilton
# Processing Record 44 of Set 6 | mantua
# Processing Record 45 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 6 | lagoa
# Processing Record 47 of Set 6 | archidona
# Processing Record 48 of Set 6 | nenjiang
# Processing Record 49 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 0 of Set 7 | port lincoln
# Processing Record 1 of Set 7 | peleduy
# Processing Record 2 of Set 7 | ust-tsilma
# Processing Record 3 of Set 7 | half moon bay
# Processing Record 4 of Set 7 | svetlogorsk
# Processing Record 5 of Set 7 | bintulu
# Processing Record 6 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 7 | bandar
# Processing Record 8 of Set 7 | zyryanka
# Processing Record 9 of Set 7 | conceicao da barra
# Processing Record 10 of Set 7 | koroni
# Processing Record 11 of Set 7 | port elizabeth
# Processing Record 12 of Set 7 | fairbanks
# Processing Record 13 of Set 7 | srednekolymsk
# Processing Record 14 of Set 7 | steinbach
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | manzhouli
# Processing Record 17 of Set 7 | grand-santi
# Processing Record 18 of Set 7 | guruvayur
# Processing Record 19 of Set 7 | dillon
# Processing Record 20 of Set 7 | clyde river
# Processing Record 21 of Set 7 | asau
# City not found. Skipping...
# Processing Record 22 of Set 7 | toamua
# City not found. Skipping...
# Processing Record 23 of Set 7 | zaragoza
# Processing Record 24 of Set 7 | nazca
# Processing Record 25 of Set 7 | chapais
# Processing Record 26 of Set 7 | odweyne
# City not found. Skipping...
# Processing Record 27 of Set 7 | ostrovnoy
# Processing Record 28 of Set 7 | derzhavinsk
# Processing Record 29 of Set 7 | norman wells
# Processing Record 30 of Set 7 | shelburne
# Processing Record 31 of Set 7 | rocha
# Processing Record 32 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 7 | kaoma
# Processing Record 34 of Set 7 | georgiyevka
# Processing Record 35 of Set 7 | bambous virieux
# Processing Record 36 of Set 7 | saint-joseph
# Processing Record 37 of Set 7 | abalak
# Processing Record 38 of Set 7 | machali
# City not found. Skipping...
# Processing Record 39 of Set 7 | emba
# Processing Record 40 of Set 7 | batagay-alyta
# Processing Record 41 of Set 7 | palembang
# Processing Record 42 of Set 7 | cayenne
# Processing Record 43 of Set 7 | cascais
# Processing Record 44 of Set 7 | togul
# Processing Record 45 of Set 7 | okahandja
# Processing Record 46 of Set 7 | clinton
# Processing Record 47 of Set 7 | los llanos de aridane
# Processing Record 48 of Set 7 | dunedin
# Processing Record 49 of Set 7 | hobyo
# Processing Record 0 of Set 8 | aswan
# Processing Record 1 of Set 8 | san juan
# Processing Record 2 of Set 8 | lingao
# Processing Record 3 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 8 | torbay
# Processing Record 5 of Set 8 | mindelo
# Processing Record 6 of Set 8 | yarmouth
# Processing Record 7 of Set 8 | yar-sale
# Processing Record 8 of Set 8 | zemen
# Processing Record 9 of Set 8 | ajdabiya
# Processing Record 10 of Set 8 | mayumba
# Processing Record 11 of Set 8 | mount gambier
# Processing Record 12 of Set 8 | dana point
# Processing Record 13 of Set 8 | gravelbourg
# Processing Record 14 of Set 8 | kokopo
# Processing Record 15 of Set 8 | porto novo
# Processing Record 16 of Set 8 | maningrida
# Processing Record 17 of Set 8 | copiapo
# Processing Record 18 of Set 8 | olafsvik
# City not found. Skipping...
# Processing Record 19 of Set 8 | beringovskiy
# Processing Record 20 of Set 8 | ekhabi
# Processing Record 21 of Set 8 | carauari
# Processing Record 22 of Set 8 | umtata
# Processing Record 23 of Set 8 | devonport
# Processing Record 24 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 8 | kiyasovo
# Processing Record 26 of Set 8 | ketchikan
# Processing Record 27 of Set 8 | spirit river
# Processing Record 28 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 8 | boueni
# Processing Record 30 of Set 8 | bend
# Processing Record 31 of Set 8 | saint-augustin
# Processing Record 32 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 33 of Set 8 | bay roberts
# Processing Record 34 of Set 8 | nioro
# Processing Record 35 of Set 8 | envira
# City not found. Skipping...
# Processing Record 36 of Set 8 | college
# Processing Record 37 of Set 8 | huilong
# Processing Record 38 of Set 8 | kaitangata
# Processing Record 39 of Set 8 | matara
# Processing Record 40 of Set 8 | mankono
# Processing Record 41 of Set 8 | port keats
# Processing Record 42 of Set 8 | caravelas
# Processing Record 43 of Set 8 | saint-francois
# Processing Record 44 of Set 8 | nantucket
# Processing Record 45 of Set 8 | aykhal
# Processing Record 46 of Set 8 | tonekabon
# Processing Record 47 of Set 8 | maragogi
# Processing Record 48 of Set 8 | salalah
# Processing Record 49 of Set 8 | kozulka
# Processing Record 0 of Set 9 | rajmahal
# Processing Record 1 of Set 9 | broome
# Processing Record 2 of Set 9 | maiduguri
# Processing Record 3 of Set 9 | vestmanna
# Processing Record 4 of Set 9 | ambulu
# Processing Record 5 of Set 9 | uyskoye
# Processing Record 6 of Set 9 | meulaboh
# Processing Record 7 of Set 9 | aquiraz
# Processing Record 8 of Set 9 | uppsala
# Processing Record 9 of Set 9 | vestmannaeyjar
# Processing Record 10 of Set 9 | morro bay
# Processing Record 11 of Set 9 | edd
# Processing Record 12 of Set 9 | zharkent
# Processing Record 13 of Set 9 | portland
# Processing Record 14 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 9 | tura
# Processing Record 16 of Set 9 | klaksvik
# Processing Record 17 of Set 9 | hualmay
# Processing Record 18 of Set 9 | antofagasta
# Processing Record 19 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 9 | qasigiannguit
# Processing Record 21 of Set 9 | cacule
# Processing Record 22 of Set 9 | dasuya
# Processing Record 23 of Set 9 | lancaster
# Processing Record 24 of Set 9 | topeka
# Processing Record 25 of Set 9 | rucheng
# Processing Record 26 of Set 9 | anchorage
# Processing Record 27 of Set 9 | ponazyrevo
# Processing Record 28 of Set 9 | tocopilla
# Processing Record 29 of Set 9 | usinsk
# Processing Record 30 of Set 9 | dustlik
# Processing Record 31 of Set 9 | nakhon phanom
# Processing Record 32 of Set 9 | kommunisticheskiy
# Processing Record 33 of Set 9 | jayanca
# Processing Record 34 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 9 | khash
# Processing Record 36 of Set 9 | vanavara
# Processing Record 37 of Set 9 | kinlochleven
# Processing Record 38 of Set 9 | sola
# Processing Record 39 of Set 9 | lakatoro
# Processing Record 40 of Set 9 | gasa
# Processing Record 41 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 9 | puerto ayacucho
# Processing Record 43 of Set 9 | bathsheba
# Processing Record 44 of Set 9 | channel-port aux basques
# Processing Record 45 of Set 9 | jarjis
# City not found. Skipping...
# Processing Record 46 of Set 9 | udachnyy
# Processing Record 47 of Set 9 | bulawayo
# Processing Record 48 of Set 9 | yaring
# Processing Record 49 of Set 9 | muroto
# Processing Record 0 of Set 10 | aitape
# Processing Record 1 of Set 10 | paka
# Processing Record 2 of Set 10 | hirara
# Processing Record 3 of Set 10 | samoded
# Processing Record 4 of Set 10 | pareora
# Processing Record 5 of Set 10 | flinders
# Processing Record 6 of Set 10 | kalianget
# Processing Record 7 of Set 10 | hovd
# Processing Record 8 of Set 10 | kuopio
# Processing Record 9 of Set 10 | heihe
# Processing Record 10 of Set 10 | samana
# Processing Record 11 of Set 10 | kudahuvadhoo
# Processing Record 12 of Set 10 | buin
# Processing Record 13 of Set 10 | bilibino
# Processing Record 14 of Set 10 | goderich
# Processing Record 15 of Set 10 | ola
# Processing Record 16 of Set 10 | yevlax
# Processing Record 17 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 18 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 10 | priladozhskiy
# Processing Record 20 of Set 10 | soverato
# Processing Record 21 of Set 10 | arauco
# Processing Record 22 of Set 10 | ankang
# Processing Record 23 of Set 10 | tamiahua
# Processing Record 24 of Set 10 | brae
# Processing Record 25 of Set 10 | ouesso
# Processing Record 26 of Set 10 | veresti
# Processing Record 27 of Set 10 | te anau
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | nioki
# Processing Record 30 of Set 10 | nurlat
# Processing Record 31 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 10 | cabedelo
# Processing Record 33 of Set 10 | marabba
# Processing Record 34 of Set 10 | makakilo city
# Processing Record 35 of Set 10 | kamariotissa
# Processing Record 36 of Set 10 | salekhard
# Processing Record 37 of Set 10 | el balyana
# City not found. Skipping...
# Processing Record 38 of Set 10 | genhe
# Processing Record 39 of Set 10 | valentin gomez farias
# Processing Record 40 of Set 10 | tsiroanomandidy
# Processing Record 41 of Set 10 | longyearbyen
# Processing Record 42 of Set 10 | sao luis de montes belos
# Processing Record 43 of Set 10 | terney
# Processing Record 44 of Set 10 | wencheng
# Processing Record 45 of Set 10 | sept-iles
# Processing Record 46 of Set 10 | langenburg
# Processing Record 47 of Set 10 | winslow
# Processing Record 48 of Set 10 | dingle
# Processing Record 49 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 0 of Set 11 | blagoyevo
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | tambovka
# Processing Record 3 of Set 11 | honningsvag
# Processing Record 4 of Set 11 | maidstone
# Processing Record 5 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 11 | severobaykalsk
# Processing Record 7 of Set 11 | payyannur
# Processing Record 8 of Set 11 | vuktyl
# Processing Record 9 of Set 11 | placido de castro
# Processing Record 10 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 11 | gerash
# Processing Record 12 of Set 11 | sabha
# Processing Record 13 of Set 11 | qinhuangdao
# Processing Record 14 of Set 11 | saint anthony
# Processing Record 15 of Set 11 | bourail
# Processing Record 16 of Set 11 | plast
# Processing Record 17 of Set 11 | coahuayana
# Processing Record 18 of Set 11 | alta floresta
# Processing Record 19 of Set 11 | uglegorsk
# Processing Record 20 of Set 11 | ixtapa
# Processing Record 21 of Set 11 | sur
# Processing Record 22 of Set 11 | magan
# Processing Record 23 of Set 11 | neuquen
# Processing Record 24 of Set 11 | la sarre
# Processing Record 25 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 11 | camocim
# Processing Record 27 of Set 11 | neryungri
# Processing Record 28 of Set 11 | netrakona
# Processing Record 29 of Set 11 | alofi
# Processing Record 30 of Set 11 | kiama
# Processing Record 31 of Set 11 | eureka
# Processing Record 32 of Set 11 | arlit
# Processing Record 33 of Set 11 | tinaquillo
# Processing Record 34 of Set 11 | newcastle
# Processing Record 35 of Set 11 | adrar
# Processing Record 36 of Set 11 | kokoda
# Processing Record 37 of Set 11 | poronaysk
# Processing Record 38 of Set 11 | isetskoye
# Processing Record 39 of Set 11 | abonnema
# Processing Record 40 of Set 11 | verkhoyansk
# Processing Record 41 of Set 11 | bangui
# Processing Record 42 of Set 11 | yumen
# Processing Record 43 of Set 11 | nelson
# Processing Record 44 of Set 11 | ossora
# Processing Record 45 of Set 11 | tashtagol
# Processing Record 46 of Set 11 | jieshi
# Processing Record 47 of Set 11 | wanaka
# Processing Record 48 of Set 11 | kattivakkam
# Processing Record 49 of Set 11 | loandjili
# Processing Record 0 of Set 12 | amahai
# Processing Record 1 of Set 12 | mount isa
# Processing Record 2 of Set 12 | puerto colombia
# Processing Record 3 of Set 12 | auray
# Processing Record 4 of Set 12 | atar
# Processing Record 5 of Set 12 | kiunga
# Processing Record 6 of Set 12 | munster
# Processing Record 7 of Set 12 | moa
# Processing Record 8 of Set 12 | samarai
# Processing Record 9 of Set 12 | werda
# Processing Record 10 of Set 12 | mayna
# Processing Record 11 of Set 12 | mattru
# Processing Record 12 of Set 12 | okhotsk
# Processing Record 13 of Set 12 | ulladulla
# Processing Record 14 of Set 12 | pandan
# Processing Record 15 of Set 12 | diamantino
# Processing Record 16 of Set 12 | prince rupert
# Processing Record 17 of Set 12 | roquetas de mar
# Processing Record 18 of Set 12 | florianopolis
# Processing Record 19 of Set 12 | tazovskiy
# Processing Record 20 of Set 12 | shitanjing
# Processing Record 21 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 22 of Set 12 | vostok
# Processing Record 23 of Set 12 | chumikan
# Processing Record 24 of Set 12 | olivenza
# Processing Record 25 of Set 12 | deputatskiy
# Processing Record 26 of Set 12 | yinchuan
# Processing Record 27 of Set 12 | hay river
# Processing Record 28 of Set 12 | along
# Processing Record 29 of Set 12 | skowhegan
# Processing Record 30 of Set 12 | okhansk
# Processing Record 31 of Set 12 | nyurba
# Processing Record 32 of Set 12 | shakiso
# Processing Record 33 of Set 12 | hammerfest
# Processing Record 34 of Set 12 | warmbad
# Processing Record 35 of Set 12 | tomatlan
# Processing Record 36 of Set 12 | nishihara
# Processing Record 37 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 38 of Set 12 | maniitsoq
# Processing Record 39 of Set 12 | mlonggo
# Processing Record 40 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 12 | porto walter
# Processing Record 42 of Set 12 | hollola
# Processing Record 43 of Set 12 | manggar
# Processing Record 44 of Set 12 | zhigansk
# Processing Record 45 of Set 12 | zaozerne
# Processing Record 46 of Set 12 | digby
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather_df = pd.DataFrame(city_data)
city_weather_df.rename(columns = {'Wind Speed':'WindSpeed'},inplace=True)
city_weather_df['absLat'] = city_weather_df['Lat'].abs()
city_weather_df.to_csv('../resources/CityWeather.csv', index=False)
city_weather_df.tail(8)

#### NOTA BENE: ON THIS OUTPUT, CASE 527 IS PORTO WALTER, BR
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 525     maniitsoq          34      GL  1570681386        46  65.42  -52.90
# 526       mlonggo          20      ID  1570681785        34  -6.53  110.70
# 527  porto walter          31      BR  1570681786        93  -8.27  -72.74
# 528       hollola          63      FI  1570681786        99  60.99   25.50
# 529       manggar          67      ID  1570681786        80  -2.88  108.27
# 530      zhigansk         100      RU  1570681369        77  66.77  123.37
# 531      zaozerne         100      UA  1570681786        94  51.37   23.94
# 532         digby         100      CA  1570681787        90  44.62  -65.76
#
#      MaxTemp  WindSpeed  absLat
# 525    35.19       4.88   65.42
# 526    93.20       9.17    6.53
# 527    71.55       1.76    8.27
# 528    37.99       1.01   60.99
# 529    81.16      11.39    2.88
# 530    20.79      20.25   66.77
# 531    48.51      13.07   51.37
# 532    48.00       1.99   44.62

# %%
## okay, yeah, that works.  but I'm not using <i> that </i> output file. 
## 'that' being the distal referent.  
## THIS being the distal referent.  
## Or ze being the proxminal referent since it's yom kippur and all.


# man i could eat some kippers about now. i'm hoNGRy.

# %%
# NOTA BENE:  I used a bigger weather file: I ran the API above a few times then cut the dupes **/ 
# it was for asthetic reasons more than data-driven: I like the way the cloud of small dots looks. **/
# %cd "C:\Users\kwlei\Documents\GitHub\Web-Design-Challenge\WebVisualizations\resources"
# Out:
# C:\Users\kwlei\Documents\GitHub\Web-Design-Challenge\WebVisualizations\resources

# %%
# LOAD THE DATA FROM THE API OUTPUT FILE 

cities = "cities.csv" 
city_weather_df = pd.read_csv(cities)
city_weather_df.tail()
# Out:
#           City  Cloudiness Country   timestamp  Humidity    Lat     Lng  \
# 1750  zhuravka           0      UA  1570050978        63  48.23   37.37
# 1751    zigong         100      CN  1570047583        91  29.34  104.78
# 1752      ziro           6      IN  1570050763        96  27.54   93.82
# 1753   zurrieq          20      MT  1570051012        83  35.83   14.47
# 1754  zyryanka         100      RU  1570050714        86  65.73  150.89
#
#       MaxTemp  WindSpeed  absLat
# 1750    54.53       6.38   48.23
# 1751    69.04       3.78   29.34
# 1752    53.40       2.42   27.54
# 1753    75.99       8.05   35.83
# 1754    26.63      15.84   65.73

# %%
city_weather_df.dtypes
# Out:
# City           object
# Cloudiness      int64
# Country        object
# timestamp       int64
# Humidity        int64
# Lat           float64
# Lng           float64
# MaxTemp       float64
# WindSpeed     float64
# absLat        float64
# dtype: object

# %%
# %cd "C:\Users\kwlei\Documents\GitHub\WebRedesign\WebVisualizations\visualizations"
# Out:
# C:\Users\kwlei\Documents\GitHub\WebRedesign\WebVisualizations\visualizations

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %%
# MAKE THE PLOTS 
plt.figure(figsize=(9,6))
plt.title("Latitude and Maximum Daily Temp")
plt.scatter(city_weather_df.Lat, city_weather_df.MaxTemp, color= 'red', marker='o', s=10)
plt.savefig('Lat_X_Temp.png')

# %%
# MAKE THE PLOTS 
plt.figure(figsize=(3,2))
plt.title("Latitude and Maximum Daily Temp")
plt.scatter(city_weather_df.Lat, city_weather_df.MaxTemp, color= 'red', marker='o', s=0.5)
plt.savefig('sm_Lat_X_Temp.png')

# %%
plt.figure(figsize=(9,6))
plt.scatter(city_weather_df.Lat, city_weather_df.Humidity, color= 'blue', marker='o', s=10)
plt.title("Latitude and Humidity")
plt.savefig('Lat_X_Humidity.png')

# %%
plt.figure(figsize=(3,2))
plt.scatter(city_weather_df.Lat, city_weather_df.Humidity, color= 'blue', s=0.5)
plt.title("Latitude and Humidity")
plt.savefig('sm_Lat_X_Humidity.png')

# %%
plt.figure(figsize=(9,6))
plt.scatter(city_weather_df.Lat, city_weather_df.Cloudiness, color = results_df.date, results_df., marker='o', s=20) 
plt.title("Latitude and Cloud Cover")
plt.savefig('Lat_X_Clouds.png')
# Out:
#   File "<ipython-input-51-fe54ef367712>", line 2
#     plt.scatter(city_weather_df.Lat, city_weather_df.Cloudiness, color = results_df.date, results_df., marker='o', s=20)
#                                                                                                      ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(3,2))
plt.scatter(city_weather_df.Lat, city_weather_df.Cloudiness, color = 'xkcd:slate', s=1) 
plt.title("Latitude and Cloud Cover")
plt.savefig('sm_Lat_X_Clouds.png')

# %%
plt.figure(figsize=(9,6))
plt.scatter(city_weather_df.Lat, city_weather_df.WindSpeed, color= 'xkcd:periwinkle', marker='o', s=15)
plt.title("Latitude and Wind Speed")
plt.savefig('Lat_X_Wind.png')

# %%
plt.figure(figsize=(3,2))
plt.scatter(city_weather_df.Lat, city_weather_df.WindSpeed, color= 'xkcd:periwinkle', s=0.75)
plt.title("Latitude and Wind Speed")
plt.savefig('sm_Lat_X_Wind.png')

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %%
# MAKE THE SAME PLOTS USING ABSOLUTE LATITUDE
plt.figure(figsize=(9,6))
plt.scatter(city_weather_df.absLat, city_weather_df.MaxTemp, color= 'xkcd:coral', marker='o', s=15)
plt.title("absval of Latitude and Maximum Daily Temp")
plt.savefig('absLat_X_Temp.png')

# %%
# MAKE THE SAME PLOTS USING ABSOLUTE LATITUDE
plt.figure(figsize=(3,2))
plt.scatter(city_weather_df.absLat, city_weather_df.MaxTemp, color= 'xkcd:coral', s=0.75)
plt.title("absval of Latitude and Maximum Daily Temp", fontsize=12)
plt.savefig('sm_absLat_X_Temp.png')

# %%
plt.figure(figsize=(9,6))
plt.scatter(city_weather_df.absLat, city_weather_df.Humidity, color= 'xkcd:ocean blue', marker='o', s=15)
plt.title("absval of Latitude and Humidity (2019.10.02)")
plt.savefig('absLat_X_Humidity.png')

# %%
plt.figure(figsize=(3,2))
plt.scatter(city_weather_df.absLat, city_weather_df.Humidity, color= 'xkcd:ocean blue', s=0.75)
plt.title("absval of Latitude and Humidity)", fontsize=12)
plt.savefig('sm_absLat_X_Humidity.png')

# %%
plt.figure(figsize=(9,6))
plt.scatter(city_weather_df.absLat, city_weather_df.Cloudiness, color = 'xkcd:dark sky blue', marker='o', s=10) 
plt.title("absval of Latitude and Cloud Cover")
plt.savefig('absLat_X_Clouds.png')

# %%
plt.figure(figsize=(3,2))
plt.scatter(city_weather_df.absLat, city_weather_df.Cloudiness, color = 'xkcd:dark sky blue', s=2) 
plt.title("absval of Latitude and Cloud Cover", fontsize=12)
plt.savefig('sm_absLat_X_Clouds.png')

# %%
plt.figure(figsize=(9,6))
plt.scatter(city_weather_df.absLat, city_weather_df.WindSpeed, color= 'xkcd:purple', marker='o', s=15)
plt.title("absval of Latitude and Wind Speed")
plt.savefig('absLat_X_Wind.png')

# %%
plt.figure(figsize=(3,2))
plt.scatter(city_weather_df.absLat, city_weather_df.WindSpeed, color= 'xkcd:purple', s=1)
plt.title("absval of Latitude and Wind Speed", fontsize=12)
plt.savefig('sm_absLat_X_Wind.png')

# %%
# %cd "C:\Users\kwlei\Documents\GitHub\WebRedesign\WebVisualizations\resources"
city_weather_df.to_csv('CityWeather2.html', index=False)
# Out:
# C:\Users\kwlei\Documents\GitHub\WebRedesign\WebVisualizations\resources
